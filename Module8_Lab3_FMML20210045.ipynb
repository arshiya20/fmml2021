# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiya20/fmml2021/blob/main/Module8_Lab3_FMML20210045.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-14 14:28:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   183MB/s    in 0.4s
#
# 2022-06-14 14:28:36 (183 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18469   1012.1643v1  Virtual e-Science infrastructures supporting W...    cs
# 4753    1211.2512v2  Minimal cost feature selection is devoted to o...    cs
# 22783  1706.07258v1  This paper describes an expectation propagatio...  stat
# 35935   1107.0036v1  A novel algorithm for actively trading stocks ...    cs
# 40740   1206.5349v2  We present a new algorithm for Independent Com...    cs
# ...             ...                                                ...   ...
# 21501   0709.2760v3  In recent years, kernel density estimation has...  stat
# 3221    1403.6706v1  Incorporating sparsity priors in learning task...  stat
# 12246  1710.10388v1  There has been a recent surge of interest in s...  stat
# 29939  1711.01714v1  Video understanding has attracted much researc...    cs
# 2446    1402.0635v3  We propose randomized least-squares value iter...  stat
#
#                                                    title  year  \
# 18469  Process Makna - A Semantic Wiki for Scientific...  2010
# 4753   Minimal cost feature selection of data with no...  2012
# 22783  Scalable Multi-Class Gaussian Process Classifi...  2017
# 35935                Can We Learn to Beat the Best Stock  2011
# 40740  Provable ICA with Unknown Gaussian Noise, and ...  2012
# ...                                                  ...   ...
# 21501  Supervised Machine Learning with a Novel Kerne...  2007
# 3221   Beyond L2-Loss Functions for Learning Sparse M...  2014
# 12246  Minimax Rates and Efficient Algorithms for Noi...  2017
# 29939  End-to-End Video Classification with Knowledge...  2017
# 2446   Generalization and Exploration via Randomized ...  2014
#
#                                                 keywords
# 18469  [infrastructures, supporting, scientific, work...
# 4753   [selection, misclassification, addressed, nume...
# 22783  [describes, expectation, propagation, classifi...
# 35935  [algorithm, presented, traditional, universal,...
# 40740  [algorithm, independent, component, performanc...
# ...                                                  ...
# 21501  [estimation, exploited, scientists, estimation...
# 3221   [incorporating, interpretable, dimensional, wi...
# 12246  [permutation, comparison, structurally, parame...
# 29939  [understanding, attracted, attention, especial...
# 2446   [randomized, iteration, reinforcement, algorit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18469    [infrastructures, supporting, scientific, work...
# 4753     [selection, misclassification, addressed, nume...
# 22783    [describes, expectation, propagation, classifi...
# 35935    [algorithm, presented, traditional, universal,...
# 40740    [algorithm, independent, component, performanc...
#                                ...
# 38070    [statistical, wikipedia, complexity, empirical...
# 26568    [localization, automatic, synthesis, estimatio...
# 15395    [alignment, comparable, consisting, contiguous...
# 30096    [performance, segmentation, sufficient, annota...
# 24575    [recognition, important, monitoring, managemen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8588 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b24b7a2a-f110-4ed0-9f69-e8aa47148de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b24b7a2a-f110-4ed0-9f69-e8aa47148de2")) {                    Plotly.newPlot(                        "b24b7a2a-f110-4ed0-9f69-e8aa47148de2",                        [{"x":["lightweight","management","knowledge","combination","intensive","interaction","supporting","interface","corporate","scientists","scientific","collaborative","intuitive","workflows","infrastructures","processes","technical","structured","execution","effective","techniques","intervals","neighborhoods","neighborhood","experimental","confidence","efficient","misclassification","discretized","numerical","distribution","selection","backtracking","algorithm","comparing","measurement","constructed","reasonable","information","addressed","considering","inference","empirically","instances","stochastic","describes","likelihood","distributions","propagation","computational","computations","predictive","furthermore","variational","assumptions","gradients","expectation","alternative","iterations","consequence","independent","sometimes","classification","approaches","significantly","approximate","relations","traditional","empirical","parameters","smoothing","statistical","historical","presented","algorithms","predictable","universal","particular","accomplish","overlooked","approximately","whitening","dimensional","accumulation","autoencoders","guarantees","introduce","covariance","component","complexity","polynomial","performance","components","implications","framework","procedures","convolutional","generalize","treatment","including","simultaneously","discriminative","available","discovered","benchmarks","treatments","difference","engineering","extractors","considers","consuming","structure","electronic","demonstrate","incorporate","application","correlated","typically","diagnoses","baselines","dependencies","embedding","therefore","superiority","predicting","important","considered","difficult","annotation","differences","variations","extraction","evaluated","automatic","alignment","segmentation","consumption","orientation","extremely","challenging","introduction","extracting","maximizing","computing","dictionaries","approximation","successful","factorization","observations","approximating","properties","depending","dictionary","established","iteratively","coherence","denoising","separation","characterized","truenorth","topological","differentiates","transmission","interconnected","comparison","recognition","handwritten","processed","simulation","revolutionary","spatiotemporal","fundamentally","methodology","conversion","implement","intuitively","interprets","neuromorphic","developing","manipulated","covariate","conditions","discussed","confounding","equivalence","potential","surrounding","variables","applications","following","boundaries","identical","admissible","adjustment","relational","optimization","necessary","generalization","evaluation","databases"],"y":[7,43,354,130,36,77,15,37,3,13,29,27,40,3,5,102,31,83,33,253,400,12,9,28,365,39,402,8,6,86,220,146,5,812,73,28,60,35,703,37,91,207,89,94,113,80,57,107,75,273,30,60,172,51,69,42,25,103,26,24,127,35,534,427,266,106,98,182,148,247,17,154,22,218,599,6,40,258,20,9,37,2,182,5,20,62,358,26,90,228,67,890,104,21,560,45,370,55,29,237,122,99,288,23,100,2,58,72,7,27,26,347,17,575,68,268,31,108,4,56,48,121,149,44,79,351,138,139,66,49,85,117,128,186,47,188,21,26,54,276,27,57,32,145,25,122,66,26,74,20,217,40,60,46,31,21,48,29,39,2,16,2,11,6,138,376,33,19,75,4,14,8,62,14,65,17,2,13,54,2,4,125,62,2,28,163,20,127,446,78,31,16,6,5,35,325,89,124,262,49],"type":"bar"},{"x":["lightweight","management","knowledge","combination","intensive","interaction","support ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Logic</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>Programming</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Inheritance</span> <span style=''>with</span> <span style=''>Overriding</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>programming</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inheritance</span> <span style=''>with</span> <span style=''>overriding</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>new</span> <span style=''>notions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>entailment</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7762237762237763);'>reasoning</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>which</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>logical</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>entailment</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inheritance</span> <span style=''>with</span> <span style=''>overriding</span> <span style=''>This</span> <span style=''>is</span> <span style=''>done</span> <span style=''>by</span> <span style=''>using</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>default</span> <span style='background-color:rgba(0, 255, 0, 0.7762237762237763);'>reasoning</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>entailment</span> <span style='background-color:rgba(0, 255, 0, 0.5934959349593496);'>relations</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>programming</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inheritance</span> <span style=''>with</span> <span style=''>overriding</span> <span style=''>and</span> <span style=''>program</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5254237288135593);'>increased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>joint</span> <span style=''>sparsity</span> <span style=''>recovery</span> <span style=''>under</span> <span style=''>the</span> <span style=''>Poisson</span> <span style=''>noise</span> <span style=''>model</span> <br/><br/><span style=''>Our</span> <span style=''>work</span> <span style=''>is</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>the</span> <span style=''>joint</span> <span style=''>sparsity</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>common</span> <span style=''>sparsity</span> <span style=''>pattern</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>by</span> <span style=''>Poisson</span> <span style=''>noise</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>both</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>(LS)</span> <span style=''>and</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>(ML)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>and</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style=''>perfect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>row</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>row</span> <span style=''>sparsity</span> <span style=''>pattern</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>Using</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>results</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>and</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>proposed</span> <span style=''>row</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>row</span> <span style=''>sparsity</span> <span style=''>pattern</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Improved</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>firstly</span> <span style=''>give</span> <span style=''>a</span> <span style=''>brief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduction</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.47916666666666663);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956523);'>maximization</span> <span style=''>(EM)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>then</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.47916666666666663);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956523);'>maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Subsequently</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>short</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>EMs</span> <span style='background-color:rgba(255, 0, 0, 0.323699421965318);'>convergence</span> <span style=''>Then</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.47916666666666663);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956523);'>maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>Gaussion</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>(GMM))</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3571428571428571);'>experiment</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.47916666666666663);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956523);'>maximization</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.35323383084577115);'>performed</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>three</span> <span style=''>cases</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialize</span> <span style=''>randomly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialize</span> <span style=''>with</span> <span style=''>result</span> <span style=''>of</span> <span style=''>K</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialize</span> <span style=''>with</span> <span style=''>result</span> <span style=''>of</span> <span style=''>K</span> <span style=''>medoids</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3571428571428571);'>experiment</span> <span style=''>result</span> <span style=''>shows</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.47916666666666663);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956523);'>maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algori ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Forest</span> <span style=''>Floor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Visualizations</span> <span style=''>of</span> <span style=''>Random</span> <span style=''>Forests</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>forest</span> <span style=''>floor</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualize</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>(RF)</span> <span style=''>models</span> <span style=''>RF</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>and</span> <span style=''>useful</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>multi</span> <span style=''>variate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>which</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>good</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>(low</span> <span style=''>variance)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptiveness</span> <span style=''>(low</span> <span style=''>bias)</span> <span style=''>Direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>RF</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>as</span> <span style=''>the</span> <span style=''>explicit</span> <span style=''>ensemble</span> <span style=''>model</span> <span style=''>of</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>trees</span> <span style=''>is</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualize</span> <span style=''>a</span> <span style=''>RF</span> <span style=''>model</span> <span style=''>fit</span> <span style=''>by</span> <span style=''>its</span> <span style=''>mapping</span> <span style=''>from</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>space</span> <span style=''>Hereby</span> <span style=''>the</span> <span style=''>user</span> <span style=''>is</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>with</span> <span style=''>the</span> <span style=''>overall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometrical</span> <span style=''>shape</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>when</span> <span style=''>needed</span> <span style=''>one</span> <span style=''>can</span> <span style=''>zoom</span> <span style=''>in</span> <span style=''>on</span> <span style=''>local</span> <span style=''>details</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>by</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09878310665712241)
# 	knowledge (0.12670007158196134)
# 	segmentation (0.06728704366499642)
# 	representation (0.12813171080887617)
# 	architecture (0.09162491052254831)
# 	information (0.2516105941302792)
# 	detection (0.12634216177523264)
# 	convolutional (0.1324266284896206)
# 	recognition (0.13457408732999285)
# 	different (0.2791696492483894)
#
# Some Statistics words are:
# 	algorithm (0.38035892323030907)
# 	theoretical (0.14905284147557327)
# 	variables (0.14057826520438685)
# 	statistical (0.1510468594217348)
# 	stochastic (0.14057826520438685)
# 	estimation (0.17048853439680958)
# 	distribution (0.18444666001994017)
# 	inference (0.18693918245264207)
# 	dimensional (0.1794616151545364)
# 	regression (0.18195413758723827)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="405f974d-a1ae-4376-8afd-451cc0c5711f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("405f974d-a1ae-4376-8afd-451cc0c5711f")) {                    Plotly.newPlot(                        "405f974d-a1ae-4376-8afd-451cc0c5711f",                        [{"x":["lightweight","management","knowledge","combination","intensive","interaction","supporting","interface","corporate","scientists","scientific","collaborative","intuitive","workflows","infrastructures","processes","technical","structured","execution","effective","techniques","intervals","neighborhoods","neighborhood","experimental","confidence","efficient","misclassification","discretized","numerical","distribution","selection","backtracking","algorithm","comparing","measurement","constructed","reasonable","information","addressed","considering","inference","empirically","instances","stochastic","describes","likelihood","distributions","propagation","computational","computations","predictive","furthermore","variational","assumptions","gradients","expectation","alternative","iterations","consequence","independent","sometimes","classification","approaches","significantly","approximate","relations","traditional","empirical","parameters","smoothing","statistical","historical","presented","algorithms","predictable","universal","particular","accomplish","overlooked","approximately","whitening","dimensional","accumulation","autoencoders","guarantees","introduce","covariance","component","complexity","polynomial","performance","components","implications","framework","procedures","convolutional","generalize","treatment","including","simultaneously","discriminative","available","discovered","benchmarks","treatments","difference","engineering","extractors","considers","consuming","structure","electronic","demonstrate","incorporate","application","correlated","typically","diagnoses","baselines","dependencies","embedding","therefore","superiority","predicting","important","considered","difficult","annotation","differences","variations","extraction","evaluated","automatic","alignment","segmentation","consumption","orientation","extremely","challenging","introduction","extracting","maximizing","computing","dictionaries","approximation","successful","factorization","observations","approximating","properties","depending","dictionary","established","iteratively","coherence","denoising","separation","characterized","truenorth","topological","differentiates","transmission","interconnected","comparison","recognition","handwritten","processed","simulation","revolutionary","spatiotemporal","fundamentally","methodology","conversion","implement","intuitively","interprets","neuromorphic","developing","manipulated","covariate","conditions","discussed","confounding","equivalence","potential","surrounding","variables","applications","following","boundaries","identical","admissible","adjustment","relational","optimization","necessary","generalization","evaluation","databases","conjunctive","probabilistic","probability","importantly","enumerate","evaluating","providing","alternate","efficiently","effectively","differential","relationship","critically","maximization","multidimensional","experiments","representation","equations","coefficients","consistently","engagement","exploiting","synthetic","perspective","threshold","graphical","consistent","addresses","heuristic","structurally","recurrent","architecture","connectionist","contextual","respectively","successes","calculate","sequences","trainable","mentioned","generated","architectures","advantage","performances","solutions","computationally","procedure","replacing","interpretation","wainwright","penalized","semidefinite","regularization","connections","enforcing"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	retrospective
# 	forecaster
# 	effortlessly
# 	unavailability
# 	precludes
# 	intriguingly
# 	heteroskedastic
# 	propensity
# 	definiteness
# 	unperturbed
# 	penalties
# 	kolmogorov
# 	decouples
# 	judiciously
# 	substantive
# 	operationalize
# 	staleness
# 	functioning
# 	assortativity
# 	quantiles
# Some words which never appear in Statistics papers:
# 	corporate
# 	truenorth
# 	revolutionary
# 	interprets
# 	connectionist
# 	navigation
# 	associate
# 	personalize
# 	upscaling
# 	plasticity
# 	syntactic
# 	agglomerates
# 	eligibility
# 	coreference
# 	equivariant
# 	entertainment
# 	formulates
# 	monocular
# 	occlusions
# 	accompany

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077112437688473e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
